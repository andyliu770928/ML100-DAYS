# %% [markdown]
# # t-SNE 範例
# * 觀察S曲線使用 t-SNE 不同 perplexity 的流形還原效果

# %%
# 載入套件
import numpy as np
import matplotlib.pyplot as plt

from matplotlib.ticker import NullFormatter
from sklearn import manifold, datasets
from time import time

# %%
plt.figure(figsize=(15,6))
# 設定模型與繪圖參數
n_samples = 500
n_components = 2
perplexities = [50, 100, 150, 200, 250, 300, 350, 400, 450]

# 設定S曲線資料點
X, color = datasets.samples_generator.make_s_curve(n_samples, random_state=0)

# 繪製資料原圖
plt.subplot(2,5,1)
plt.title("Original")
plt.scatter(X[:, 0], X[:, 2], c=color)
plt.axis('tight')

for i, perplexity in enumerate(perplexities):
    t0 = time()
    tsne = manifold.TSNE(n_components=n_components, init='random',
                         random_state=0, perplexity=perplexity)
    Y = tsne.fit_transform(X)
    t1 = time()
    
    print("circles, perplexity=%d in %.2g sec" % (perplexity, t1 - t0))
    plt.subplot(2,5,i+2)
    plt.title("Perplexity=%d" % perplexity)
    plt.scatter(Y[:, 0], Y[:, 1], c=color)
    plt.axis('tight')
    
plt.show()
# Out:
# circles, perplexity=50 in 3.4 sec
# circles, perplexity=100 in 5.6 sec
# circles, perplexity=150 in 6.5 sec
# circles, perplexity=200 in 5.2 sec
# circles, perplexity=250 in 4.6 sec
# circles, perplexity=300 in 4.9 sec
# circles, perplexity=350 in 5.7 sec
# circles, perplexity=400 in 6.1 sec
# circles, perplexity=450 in 4.4 sec

# %% [markdown]
# n_samples需調高至500，比較能看到S型，但是沒出現跟原圖一樣的圖形
